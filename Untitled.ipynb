# %%
include("main.jl")
# Out:
# ✅ Packages loaded!
# import MLJLIBSVMInterface ✔
# import NearestNeighborModels ✔
# import MLJDecisionTreeInterface ✔
# ✅ Course utilities loaded (includes modelCrossValidation, confusionMatrix, etc.)
# ✅ Custom preprocessing utilities loaded!
#
# ...
# 📂 LOADING DATA
# ...
# Original dataset size: (1496586, 16)
# [ Info: For silent loading, specify `verbosity=0`.
# [ Info: For silent loading, specify `verbosity=0`.
# [ Info: For silent loading, specify `verbosity=0`.
# Original fraud distribution:
#   Non-fraud: 1421526
#   Fraud:     75060
#
# ...
# 🎯 CREATING 3-CLASS TARGET
# ...
# LoadError: UndefVarError: `create_risk_classes` not defined in `Main`
# Hint: It looks like two or more modules export different bindings with this name, resulting in ambiguity. Try explicitly importing it from a particular module, or qualifying the name with the module it should come from.
# in expression starting at C:\Users\gianluca\Desktop\fraud-detections\main.jl:96
#
# Stacktrace:
#  [1] top-level scope
# ...
